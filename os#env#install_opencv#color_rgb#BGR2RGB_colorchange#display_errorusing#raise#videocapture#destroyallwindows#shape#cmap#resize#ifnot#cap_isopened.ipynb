# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.sys.path
# Out:
# ['/Users/shreykhandelwal/jupyter_lab_projects_opencv',
#  '/Users/shreykhandelwal/opt/anaconda3/lib/python38.zip',
#  '/Users/shreykhandelwal/opt/anaconda3/lib/python3.8',
#  '/Users/shreykhandelwal/opt/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/Users/shreykhandelwal/opt/anaconda3/lib/python3.8/site-packages',
#  '/Users/shreykhandelwal/opt/anaconda3/lib/python3.8/site-packages/aeosa',
#  '/Users/shreykhandelwal/opt/anaconda3/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg',
#  '/Users/shreykhandelwal/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/shreykhandelwal/.ipython']

# %%
conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /Users/shreykhandelwal/opt/anaconda3
# myenv                    /Users/shreykhandelwal/opt/anaconda3/envs/myenv
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/8b/72/ce197a5650640f77342b3084be18783dc99debfcf20e2d98cde54050c97b/opencv_python-4.5.3.56-cp38-cp38-macosx_10_15_x86_64.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fd001040970>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /packages/8b/72/ce197a5650640f77342b3084be18783dc99debfcf20e2d98cde54050c97b/opencv_python-4.5.3.56-cp38-cp38-macosx_10_15_x86_64.whl
# ...

# %%
import cv2

# %%
img = cv2.imread('/Users/shreykhandelwal/Desktop/image.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (596, 1134, 3)

# %%
plt.imshow(img)

# %%
img_fix = cv2.cvtColor(img,
                      cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_fix)

# %%
img1 = cv2.imread('/Users/shreykhandelwal/Desktop/image.png')
cv2.imshow(' input image', img1)
# Out:
# numpy.ndarray

# %%
gray_img = cv2.imread('/Users/shreykhandelwal/Desktop/image.png', cv2.IMREAD_GRAYSCALE)
cv2.imwrite('/Users/shreykhandelwal/Desktop/output.png', gray_img)
# Out:
# True

# %%
cap = cv2.VideoCapture(0)

# %%
if not cap.isOpened():
    raise IOError("error")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-d1513a5d275e> in <module>
#       1 if not cap.isOpened():
# ----> 2     raise IOError("error")
#       3
#
# OSError: error

# %%
cap.release()

cv2.destroyAllWindows()

# %%
img_gray = cv2.imread('/Users/shreykhandelwal/Desktop/image.png',
                     cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (596, 1134)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
img_new = cv2.resize(img_fix, 
                    (400,400))

# %%
plt.imshow(img_new)
